# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# ## Retrieving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 737

# %% [markdown]
# ## Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | east wenatchee bench
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | yar-sale
# Processing Record 13 of Set 1 | nome
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | altay
# Processing Record 17 of Set 1 | talara
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | cap malheureux
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | bathsheba
# Processing Record 27 of Set 1 | beringovskiy
# Processing Record 28 of Set 1 | pangnirtung
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | waterfoot
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | avera
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | kudat
# Processing Record 40 of Set 1 | iwakuni
# Processing Record 41 of Set 1 | coos bay
# Processing Record 42 of Set 1 | kalmar
# Processing Record 43 of Set 1 | nhulunbuy
# Processing Record 44 of Set 1 | paciran
# Processing Record 45 of Set 1 | mackenzie
# Processing Record 46 of Set 1 | vanavara
# Processing Record 47 of Set 1 | mana
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | yerbogachen
# Processing Record 1 of Set 2 | turukhansk
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | bundi
# Processing Record 7 of Set 2 | husavik
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | grand gaube
# Processing Record 10 of Set 2 | aklavik
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | conde
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | beloha
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | bataipora
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | ginda
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | omboue
# Processing Record 26 of Set 2 | tucuman
# Processing Record 27 of Set 2 | batagay
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | barra do corda
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | salvador
# Processing Record 34 of Set 2 | pomichna
# Processing Record 35 of Set 2 | kyaikkami
# Processing Record 36 of Set 2 | grindavik
# Processing Record 37 of Set 2 | ixtapa
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | pouembout
# Processing Record 40 of Set 2 | cantagallo
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | namtsy
# Processing Record 43 of Set 2 | helong
# Processing Record 44 of Set 2 | ambilobe
# Processing Record 45 of Set 2 | setermoen
# Processing Record 46 of Set 2 | port blair
# Processing Record 47 of Set 2 | anadyr
# Processing Record 48 of Set 2 | bosaso
# Processing Record 49 of Set 2 | havelock
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | taltal
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | sioux lookout
# Processing Record 4 of Set 3 | porto belo
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 3 | bijie
# Processing Record 9 of Set 3 | matara
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | kahului
# Processing Record 12 of Set 3 | nicoya
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 3 | namatanai
# Processing Record 16 of Set 3 | cassia
# Processing Record 17 of Set 3 | camargo
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | bonavista
# Processing Record 20 of Set 3 | bowen
# Processing Record 21 of Set 3 | samarai
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | punta arenas
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | san lazaro
# Processing Record 31 of Set 3 | tianpeng
# Processing Record 32 of Set 3 | lompoc
# Processing Record 33 of Set 3 | nemuro
# Processing Record 34 of Set 3 | shizunai
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | barbosa
# Processing Record 37 of Set 3 | port moresby
# Processing Record 38 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 3 | kilindoni
# Processing Record 40 of Set 3 | cedartown
# Processing Record 41 of Set 3 | nelson bay
# Processing Record 42 of Set 3 | jand
# Processing Record 43 of Set 3 | pedernales
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | ledyard
# Processing Record 47 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | nouadhibou
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | leopold
# Processing Record 4 of Set 4 | takoradi
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | shimoda
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | puerto madryn
# Processing Record 10 of Set 4 | san gabriel
# Processing Record 11 of Set 4 | bud
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | ust-karsk
# Processing Record 16 of Set 4 | atar
# Processing Record 17 of Set 4 | pochutla
# Processing Record 18 of Set 4 | necochea
# Processing Record 25 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | alice springs
# Processing Record 28 of Set 4 | dyersburg
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 4 | hamilton
# Processing Record 32 of Set 4 | usinsk
# Processing Record 33 of Set 4 | vostok
# Processing Record 34 of Set 4 | paraiso
# Processing Record 35 of Set 4 | idrinskoye
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 4 | sinfra
# Processing Record 39 of Set 4 | praia
# Processing Record 40 of Set 4 | ingham
# Processing Record 41 of Set 4 | manuk mangkaw
# Processing Record 42 of Set 4 | cabatuan
# Processing Record 43 of Set 4 | minsk
# Processing Record 44 of Set 4 | carutapera
# Processing Record 45 of Set 4 | magadan
# Processing Record 46 of Set 4 | grimari
# City not found. Skipping...
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | lakhimpur
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | biltine
# Processing Record 2 of Set 5 | gwadar
# Processing Record 3 of Set 5 | riyadh
# Processing Record 4 of Set 5 | lalmohan
# Processing Record 5 of Set 5 | tessalit
# Processing Record 6 of Set 5 | ust-nera
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | diffa
# Processing Record 9 of Set 5 | banda aceh
# Processing Record 10 of Set 5 | pontal do parana
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | puerto ayora
# Processing Record 13 of Set 5 | constantine
# Processing Record 14 of Set 5 | meulaboh
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | chicama
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | denpasar
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | ancud
# Processing Record 24 of Set 5 | teguise
# Processing Record 25 of Set 5 | shar
# Processing Record 26 of Set 5 | remicourt
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | bua yai
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | shirokiy
# Processing Record 32 of Set 5 | lillooet
# Processing Record 33 of Set 5 | korla
# Processing Record 34 of Set 5 | acajutla
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | novosheshminsk
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | ormond beach
# Processing Record 39 of Set 5 | texarkana
# Processing Record 40 of Set 5 | okhotsk
# Processing Record 41 of Set 5 | provideniya
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | lander
# Processing Record 44 of Set 5 | raudeberg
# Processing Record 45 of Set 5 | asau
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | chhuikhadan
# Processing Record 48 of Set 5 | tabas
# Processing Record 49 of Set 5 | pangody
# Processing Record 50 of Set 5 | touros
# Processing Record 1 of Set 6 | mount isa
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | sakakah
# Processing Record 4 of Set 6 | sao luiz gonzaga
# Processing Record 5 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 6 | bafra
# Processing Record 7 of Set 6 | khandyga
# Processing Record 8 of Set 6 | palm coast
# Processing Record 9 of Set 6 | porto walter
# Processing Record 10 of Set 6 | olinda
# Processing Record 11 of Set 6 | poum
# Processing Record 12 of Set 6 | yarada
# Processing Record 13 of Set 6 | plettenberg bay
# Processing Record 14 of Set 6 | saint-philippe
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | arraial do cabo
# Processing Record 17 of Set 6 | haian
# Processing Record 18 of Set 6 | mpika
# Processing Record 19 of Set 6 | mnogovershinnyy
# Processing Record 20 of Set 6 | polovinnoye
# Processing Record 21 of Set 6 | rostovka
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | sol-iletsk
# Processing Record 25 of Set 6 | salamanca
# Processing Record 26 of Set 6 | xining
# Processing Record 27 of Set 6 | aranos
# Processing Record 28 of Set 6 | la paz
# Processing Record 29 of Set 6 | saint anthony
# Processing Record 30 of Set 6 | kidal
# Processing Record 31 of Set 6 | bereda
# Processing Record 32 of Set 6 | goundam
# Processing Record 33 of Set 6 | peniche
# Processing Record 34 of Set 6 | nandikotkur
# Processing Record 35 of Set 6 | buritis
# Processing Record 36 of Set 6 | longyearbyen
# Processing Record 37 of Set 6 | sao joao da barra
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | port hedland
# Processing Record 40 of Set 6 | buala
# Processing Record 41 of Set 6 | sehithwa
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | calabozo
# Processing Record 44 of Set 6 | maykor
# Processing Record 45 of Set 6 | kodinsk
# Processing Record 46 of Set 6 | raga
# Processing Record 47 of Set 6 | kambi
# Processing Record 48 of Set 6 | marrakesh
# Processing Record 49 of Set 6 | terra boa
# Processing Record 50 of Set 6 | chiredzi
# Processing Record 1 of Set 7 | santa isabel do rio negro
# Processing Record 2 of Set 7 | wagar
# Processing Record 3 of Set 7 | jaguarari
# Processing Record 4 of Set 7 | meadow lake
# Processing Record 5 of Set 7 | djenne
# Processing Record 6 of Set 7 | taywarah
# Processing Record 7 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 7 | iberia
# Processing Record 9 of Set 7 | linhares
# Processing Record 10 of Set 7 | skjervoy
# Processing Record 11 of Set 7 | san rafael
# Processing Record 12 of Set 7 | agirish
# Processing Record 13 of Set 7 | skibbereen
# Processing Record 14 of Set 7 | borogontsy
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | rio pardo de minas
# Processing Record 17 of Set 7 | maniitsoq
# Processing Record 18 of Set 7 | portland
# Processing Record 19 of Set 7 | molokovo
# Processing Record 20 of Set 7 | beisfjord
# Processing Record 21 of Set 7 | ostrovnoy
# Processing Record 22 of Set 7 | seabra
# Processing Record 23 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 24 of Set 7 | odweyne
# Processing Record 25 of Set 7 | bilibino
# Processing Record 26 of Set 7 | narnaul
# Processing Record 27 of Set 7 | nara
# Processing Record 28 of Set 7 | palu
# Processing Record 29 of Set 7 | coahuayana
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | bodden town
# Processing Record 33 of Set 7 | ko samui
# Processing Record 34 of Set 7 | moose factory
# Processing Record 35 of Set 7 | bhainsa
# Processing Record 36 of Set 7 | lamu
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | egvekinot
# Processing Record 39 of Set 7 | khatanga
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | guerrero negro
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | seybaplaya
# Processing Record 44 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 7 | creel
# Processing Record 46 of Set 7 | cabo rojo
# Processing Record 47 of Set 7 | salihorsk
# Processing Record 48 of Set 7 | polewali
# Processing Record 49 of Set 7 | tarabuco
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 1 of Set 8 | tuatapere
# Processing Record 2 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | russell
# Processing Record 5 of Set 8 | hun
# Processing Record 6 of Set 8 | esso
# Processing Record 7 of Set 8 | miles city
# Processing Record 8 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 8 | ojhar
# Processing Record 10 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 8 | roma
# Processing Record 12 of Set 8 | balkhash
# Processing Record 13 of Set 8 | manzhouli
# Processing Record 14 of Set 8 | ouesso
# Processing Record 15 of Set 8 | zaykovo
# Processing Record 16 of Set 8 | izmaylovo
# Processing Record 17 of Set 8 | andenes
# Processing Record 18 of Set 8 | miracema do tocantins
# Processing Record 19 of Set 8 | khorramshahr
# Processing Record 20 of Set 8 | sibolga
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | cubulco
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | surgut
# Processing Record 25 of Set 8 | kavieng
# Processing Record 26 of Set 8 | esperance
# Processing Record 27 of Set 8 | saldanha
# Processing Record 28 of Set 8 | kannur
# Processing Record 29 of Set 8 | kolokani
# Processing Record 30 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 8 | kings mountain
# Processing Record 32 of Set 8 | bisira
# Processing Record 33 of Set 8 | evensk
# Processing Record 34 of Set 8 | kabompo
# Processing Record 35 of Set 8 | noumea
# Processing Record 36 of Set 8 | faya
# Processing Record 37 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 8 | kasongo-lunda
# Processing Record 39 of Set 8 | coihueco
# Processing Record 40 of Set 8 | burica
# City not found. Skipping...
# Processing Record 41 of Set 8 | abu samrah
# Processing Record 42 of Set 8 | boksitogorsk
# Processing Record 43 of Set 8 | haines junction
# Processing Record 44 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 8 | yichun
# Processing Record 46 of Set 8 | te karaka
# Processing Record 47 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | ankpa
# Processing Record 50 of Set 8 | gubskaya
# Processing Record 1 of Set 9 | hokitika
# Processing Record 2 of Set 9 | acarau
# Processing Record 3 of Set 9 | malanje
# Processing Record 4 of Set 9 | irece
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | jibuti
# Processing Record 7 of Set 9 | socoltenango
# Processing Record 8 of Set 9 | phan thiet
# Processing Record 9 of Set 9 | witney
# Processing Record 10 of Set 9 | protivin
# Processing Record 11 of Set 9 | itacarambi
# Processing Record 12 of Set 9 | sangar
# Processing Record 13 of Set 9 | neiafu
# Processing Record 14 of Set 9 | fairbanks
# Processing Record 15 of Set 9 | myitkyina
# Processing Record 16 of Set 9 | bolshoy uluy
# City not found. Skipping...
# Processing Record 17 of Set 9 | wairoa
# Processing Record 18 of Set 9 | bartica
# Processing Record 19 of Set 9 | raymondville
# Processing Record 20 of Set 9 | moree
# Processing Record 21 of Set 9 | boralday
# Processing Record 22 of Set 9 | the valley
# Processing Record 23 of Set 9 | gizo
# Processing Record 24 of Set 9 | gigmoto
# Processing Record 25 of Set 9 | bambous virieux
# Processing Record 26 of Set 9 | tigil
# Processing Record 27 of Set 9 | shingu
# Processing Record 28 of Set 9 | malakal
# Processing Record 29 of Set 9 | cervo
# Processing Record 30 of Set 9 | comarapa
# Processing Record 31 of Set 9 | uige
# Processing Record 32 of Set 9 | limerick
# Processing Record 33 of Set 9 | arinos
# Processing Record 34 of Set 9 | muravlenko
# Processing Record 35 of Set 9 | port macquarie
# Processing Record 36 of Set 9 | gaoual
# Processing Record 37 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 38 of Set 9 | umm kaddadah
# Processing Record 39 of Set 9 | willowmore
# Processing Record 40 of Set 9 | bonthe
# Processing Record 41 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 9 | bridlington
# Processing Record 43 of Set 9 | port lincoln
# Processing Record 44 of Set 9 | avesta
# Processing Record 45 of Set 9 | petrovsk
# Processing Record 46 of Set 9 | tual
# Processing Record 47 of Set 9 | bubaque
# Processing Record 48 of Set 9 | burnie
# Processing Record 49 of Set 9 | tocache
# Processing Record 50 of Set 9 | tiznit
# Processing Record 1 of Set 10 | jeremoabo
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | urengoy
# Processing Record 4 of Set 10 | parabel
# Processing Record 5 of Set 10 | kumano
# Processing Record 6 of Set 10 | cacule
# Processing Record 7 of Set 10 | gorlice
# Processing Record 8 of Set 10 | goure
# Processing Record 9 of Set 10 | emba
# Processing Record 10 of Set 10 | taoudenni
# Processing Record 11 of Set 10 | douglas
# Processing Record 12 of Set 10 | aldan
# Processing Record 13 of Set 10 | los llanos de aridane
# Processing Record 14 of Set 10 | kibala
# Processing Record 15 of Set 10 | susehri
# Processing Record 16 of Set 10 | cherat
# Processing Record 17 of Set 10 | port hardy
# Processing Record 18 of Set 10 | quatre cocos
# Processing Record 19 of Set 10 | manono
# Processing Record 20 of Set 10 | anloga
# Processing Record 21 of Set 10 | san cristobal
# Processing Record 22 of Set 10 | peno
# Processing Record 23 of Set 10 | griffith
# Processing Record 24 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 10 | kastamonu
# Processing Record 26 of Set 10 | misratah
# Processing Record 27 of Set 10 | maragogi
# Processing Record 28 of Set 10 | rio verde de mato grosso
# Processing Record 29 of Set 10 | cayenne
# Processing Record 30 of Set 10 | ust-omchug
# Processing Record 31 of Set 10 | mareeba
# Processing Record 32 of Set 10 | dunedin
# Processing Record 33 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 10 | acapulco
# Processing Record 35 of Set 10 | lacolle
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | sumbe
# Processing Record 38 of Set 10 | zhigansk
# Processing Record 39 of Set 10 | verkhoyansk
# Processing Record 40 of Set 10 | astana
# Processing Record 41 of Set 10 | alugan
# Processing Record 42 of Set 10 | peski
# Processing Record 43 of Set 10 | hofn
# Processing Record 44 of Set 10 | newport
# Processing Record 45 of Set 10 | gamba
# Processing Record 46 of Set 10 | naberera
# Processing Record 47 of Set 10 | orchard homes
# Processing Record 48 of Set 10 | petropavl
# Processing Record 49 of Set 10 | studina
# Processing Record 50 of Set 10 | afonso bezerra
# Processing Record 1 of Set 11 | darnah
# Processing Record 2 of Set 11 | palora
# Processing Record 3 of Set 11 | kushiro
# Processing Record 4 of Set 11 | dingzhou
# Processing Record 5 of Set 11 | maningrida
# Processing Record 6 of Set 11 | araouane
# Processing Record 7 of Set 11 | barra dos coqueiros
# Processing Record 8 of Set 11 | vidim
# Processing Record 9 of Set 11 | waingapu
# Processing Record 10 of Set 11 | hervey bay
# Processing Record 11 of Set 11 | severnoye
# Processing Record 12 of Set 11 | muroto
# Processing Record 13 of Set 11 | labuhan
# Processing Record 14 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | tsagan aman
# Processing Record 16 of Set 11 | antofagasta
# Processing Record 17 of Set 11 | nguru
# Processing Record 18 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 11 | taree
# Processing Record 20 of Set 11 | santiago atitlan
# Processing Record 21 of Set 11 | balabac
# Processing Record 22 of Set 11 | ormara
# Processing Record 23 of Set 11 | khaga
# Processing Record 24 of Set 11 | bairiki
# Processing Record 25 of Set 11 | governador valadares
# Processing Record 26 of Set 11 | richards bay
# Processing Record 27 of Set 11 | zima
# Processing Record 28 of Set 11 | santiago del estero
# Processing Record 29 of Set 11 | pitimbu
# Processing Record 30 of Set 11 | constitucion
# Processing Record 31 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | mogadishu
# Processing Record 33 of Set 11 | panguna
# Processing Record 34 of Set 11 | ural
# Processing Record 35 of Set 11 | geesthacht
# Processing Record 36 of Set 11 | jabinyanah
# Processing Record 37 of Set 11 | canavieiras
# Processing Record 38 of Set 11 | kununurra
# Processing Record 39 of Set 11 | naze
# Processing Record 40 of Set 11 | qasigiannguit
# Processing Record 41 of Set 11 | porto novo
# Processing Record 42 of Set 11 | tatawin
# Processing Record 43 of Set 11 | sao simao
# Processing Record 44 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 11 | krasnogorskoye
# Processing Record 46 of Set 11 | asmara
# Processing Record 47 of Set 11 | berlevag
# Processing Record 48 of Set 11 | bukachacha
# Processing Record 49 of Set 11 | yerky
# Processing Record 50 of Set 11 | kamaishi
# Processing Record 1 of Set 12 | brae
# Processing Record 2 of Set 12 | sur
# Processing Record 3 of Set 12 | saint george
# Processing Record 4 of Set 12 | hashtrud
# Processing Record 5 of Set 12 | ravar
# Processing Record 6 of Set 12 | san andres
# Processing Record 7 of Set 12 | lewistown
# Processing Record 8 of Set 12 | gatesville
# Processing Record 9 of Set 12 | kade
# Processing Record 10 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 11 of Set 12 | kupang
# Processing Record 12 of Set 12 | dubai
# Processing Record 13 of Set 12 | mulege
# Processing Record 14 of Set 12 | dawson
# Processing Record 15 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 12 | mayo
# Processing Record 17 of Set 12 | det udom
# Processing Record 18 of Set 12 | ancona
# Processing Record 19 of Set 12 | mali
# Processing Record 20 of Set 12 | senno
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | bagdarin
# Processing Record 23 of Set 12 | sao joao do piaui
# Processing Record 24 of Set 12 | kousseri
# Processing Record 25 of Set 12 | yumen
# Processing Record 26 of Set 12 | kutum
# Processing Record 27 of Set 12 | manado
# Processing Record 28 of Set 12 | tahoua
# Processing Record 29 of Set 12 | bezdan
# Processing Record 30 of Set 12 | uyemskiy
# Processing Record 31 of Set 12 | manaure
# Processing Record 32 of Set 12 | abha
# Processing Record 33 of Set 12 | machhlishahr
# Processing Record 34 of Set 12 | kulhudhuffushi
# Processing Record 35 of Set 12 | inhambane
# Processing Record 36 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 12 | edd
# Processing Record 38 of Set 12 | margate
# Processing Record 39 of Set 12 | mandera
# Processing Record 40 of Set 12 | balestrand
# Processing Record 41 of Set 12 | ivankiv
# Processing Record 42 of Set 12 | seoul
# Processing Record 43 of Set 12 | barcelos
# Processing Record 44 of Set 12 | phuket
# Processing Record 45 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 12 | sept-iles
# Processing Record 47 of Set 12 | springbok
# Processing Record 48 of Set 12 | shymkent
# Processing Record 49 of Set 12 | manacapuru
# Processing Record 50 of Set 12 | zyryanka
# Processing Record 1 of Set 13 | walvis bay
# Processing Record 2 of Set 13 | cacu
# Processing Record 3 of Set 13 | camana
# Processing Record 4 of Set 13 | laohekou
# Processing Record 5 of Set 13 | ambulu
# Processing Record 6 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 7 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 13 | sakaiminato
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | mantua
# Processing Record 11 of Set 13 | atambua
# Processing Record 12 of Set 13 | zemio
# Processing Record 13 of Set 13 | lingyuan
# Processing Record 14 of Set 13 | luanshya
# Processing Record 15 of Set 13 | kartuzy
# Processing Record 16 of Set 13 | alghero
# Processing Record 17 of Set 13 | agadez
# Processing Record 18 of Set 13 | adwa
# Processing Record 19 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 13 | tashtagol
# Processing Record 21 of Set 13 | ulladulla
# Processing Record 22 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 23 of Set 13 | carupano
# Processing Record 24 of Set 13 | asino
# Processing Record 25 of Set 13 | caorle
# Processing Record 26 of Set 13 | placido de castro
# Processing Record 27 of Set 13 | fort nelson
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | pinahat
# Processing Record 30 of Set 13 | tagusao
# Processing Record 31 of Set 13 | mao
# Processing Record 32 of Set 13 | genc
# Processing Record 33 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 13 | sobolevo
# Processing Record 35 of Set 13 | ust-kulom
# Processing Record 36 of Set 13 | tilichiki
# Processing Record 37 of Set 13 | janakpur
# Processing Record 38 of Set 13 | pandan
# Processing Record 39 of Set 13 | colares
# Processing Record 40 of Set 13 | anori
# Processing Record 41 of Set 13 | katangli
# Processing Record 42 of Set 13 | padang
# Processing Record 43 of Set 13 | hoa binh
# Processing Record 44 of Set 13 | saint-joseph
# Processing Record 45 of Set 13 | sisophon
# Processing Record 46 of Set 13 | khokhlovo
# Processing Record 47 of Set 13 | togur
# Processing Record 48 of Set 13 | anzio
# Processing Record 49 of Set 13 | kushima
# Processing Record 50 of Set 13 | leshukonskoye
# Processing Record 1 of Set 14 | bonfim
# Processing Record 2 of Set 14 | isabela
# Processing Record 3 of Set 14 | vemalwada
# Processing Record 4 of Set 14 | ust-ilimsk
# Processing Record 5 of Set 14 | jiangyan
# Processing Record 6 of Set 14 | naryan-mar
# Processing Record 7 of Set 14 | phalodi
# Processing Record 8 of Set 14 | rio grande
# Processing Record 9 of Set 14 | rancho veloz
# Processing Record 10 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 11 of Set 14 | imisli
# City not found. Skipping...
# Processing Record 12 of Set 14 | hazorasp
# Processing Record 13 of Set 14 | qaqortoq
# Processing Record 14 of Set 14 | bogorodsk
# Processing Record 15 of Set 14 | puerto colombia
# Processing Record 16 of Set 14 | puerto leguizamo
# Processing Record 17 of Set 14 | svetlogorsk
# Processing Record 18 of Set 14 | san quintin
# Processing Record 19 of Set 14 | namibe
# Processing Record 20 of Set 14 | mahuva
# Processing Record 21 of Set 14 | cozumel
# Processing Record 22 of Set 14 | komsomolskiy
# Processing Record 23 of Set 14 | las varas
# Processing Record 24 of Set 14 | manacor
# Processing Record 25 of Set 14 | boueni
# Processing Record 26 of Set 14 | la ronge
# Processing Record 27 of Set 14 | zhanjiang
# Processing Record 28 of Set 14 | inuvik
# Processing Record 29 of Set 14 | mayskiy
# Processing Record 30 of Set 14 | belozerskoye
# Processing Record 31 of Set 14 | bahia blanca
# Processing Record 32 of Set 14 | klaksvik
# Processing Record 33 of Set 14 | itoman
# Processing Record 34 of Set 14 | kargasok
# Processing Record 35 of Set 14 | northam
# Processing Record 36 of Set 14 | ewa beach
# Processing Record 37 of Set 14 | natal
# Processing Record 38 of Set 14 | vallenar
# Processing Record 39 of Set 14 | gejiu
# Processing Record 40 of Set 14 | aviles
# Processing Record 41 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 14 | garowe
# Processing Record 43 of Set 14 | ibipeba
# Processing Record 44 of Set 14 | contamana
# Processing Record 45 of Set 14 | karratha
# Processing Record 46 of Set 14 | melita
# Processing Record 47 of Set 14 | matay
# Processing Record 48 of Set 14 | pokaran
# Processing Record 49 of Set 14 | huaicheng
# Processing Record 50 of Set 14 | telimele
# Processing Record 1 of Set 15 | neverkino
# Processing Record 2 of Set 15 | dumai
# Processing Record 3 of Set 15 | champerico
# Processing Record 4 of Set 15 | byron bay
# Processing Record 5 of Set 15 | chivilcoy
# Processing Record 6 of Set 15 | obilnoye
# Processing Record 7 of Set 15 | mariental
# Processing Record 8 of Set 15 | buraydah
# Processing Record 9 of Set 15 | road town
# Processing Record 10 of Set 15 | rock springs
# Processing Record 11 of Set 15 | yuci
# Processing Record 12 of Set 15 | itupiranga
# Processing Record 13 of Set 15 | san policarpo
# Processing Record 14 of Set 15 | alta floresta
# Processing Record 15 of Set 15 | san ignacio
# Processing Record 16 of Set 15 | rorvik
# Processing Record 17 of Set 15 | tazovskiy
# Processing Record 18 of Set 15 | gat
# Processing Record 19 of Set 15 | erdenet
# Processing Record 20 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 15 | venado tuerto
# Processing Record 22 of Set 15 | kungurtug
# Processing Record 23 of Set 15 | donghai
# Processing Record 24 of Set 15 | sorland
# Processing Record 25 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 15 | tomatlan
# Processing Record 27 of Set 15 | kaeo
# Processing Record 28 of Set 15 | ambon
# Processing Record 29 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 15 | asfi
# Processing Record 31 of Set 15 | honiara
# Processing Record 32 of Set 15 | bodaybo
# Processing Record 33 of Set 15 | sudak
# Processing Record 34 of Set 15 | manoel urbano
# Processing Record 35 of Set 15 | anna
# Processing Record 36 of Set 15 | rognan
# Processing Record 37 of Set 15 | belaya gora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Bluff      NZ -46.6000  168.3333     56.32        83
# 1                Kodiak      US  57.7900 -152.4072     35.11        75
# 2               Ushuaia      AR -54.8000  -68.3000     33.46        93
# 3  East Wenatchee Bench      US  47.4257 -120.2812     39.42        90
# 4             Busselton      AU -33.6500  115.3333     76.08        41
# 5                 Airai      TL  -8.9266  125.4092     76.42        56
# 6                  Lebu      CL -37.6167  -73.6500     53.08        91
# 7                Faanui      PF -16.4833 -151.7500     80.26        74
# 8           Yellowknife      CA  62.4560 -114.3525     -1.71        91
# 9         Leningradskiy      RU  69.3833  178.4167    -12.48        87
#
#    Cloudiness  Wind Speed Current Description
# 0         100       13.00          light rain
# 1          90       13.80          light snow
# 2          90       20.71          heavy snow
# 3          20        8.05          few clouds
# 4         100        7.56     overcast clouds
# 5          70        1.57       broken clouds
# 6          14       17.63          few clouds
# 7          10       15.57           clear sky
# 8          20        5.75          few clouds
# 9           5        3.11           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
